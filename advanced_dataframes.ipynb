# %% [markdown]
# # Exercises II

# %% [markdown]
# 1. Copy the users and roles DataFrames from the examples above.

# %%
# imports
import pandas as pd
import numpy as np

# %%
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# 2. What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, left_on='role_id', right_on='id', how='right', indicator=True)
# use only keys from right frame, similar to a SQL right outer join; preserve key order.
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %% [markdown]
# 3. What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, left_on='role_id', right_on='id', how='outer', indicator=True)
# use union of keys from both frames, similar to a SQL full outer join; sort keys lexicographically.
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %% [markdown]
# 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
users.merge(roles, how='outer', indicator=True)
# you get all of the data from both of the dataframes, creates a mess where you don't know which value from one table is associated with the other table.
# Out:
#    id       name  role_id      _merge
# 0   1        bob      1.0   left_only
# 1   2        joe      2.0   left_only
# 2   3      sally      3.0   left_only
# 3   4       adam      3.0   left_only
# 4   5       jane      NaN   left_only
# 5   6       mike      NaN   left_only
# 6   1      admin      NaN  right_only
# 7   2     author      NaN  right_only
# 8   3   reviewer      NaN  right_only
# 9   4  commenter      NaN  right_only

# %% [markdown]
# 5. Load the mpg dataset from PyDataset.

# %%
from pydataset import data
mpg = data('mpg')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# 6. Output and read the documentation for the mpg dataset.

# %%
mpg.info()
mpg
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# ...

# %% [markdown]
# 7. How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# 8. Check out your column names and perform any cleanup you may want on them.

# %%
mpg.rename(columns = {'cty': 'city', 'hwy': 'highway'}, inplace = True)

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %% [markdown]
# 9. Display the summary statistics for the dataset.

# %%
mpg.describe()
# Out:
#             displ         year         cyl        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# 10. How many different manufacturers are there?

# %%
mpg['manufacturer'].nunique()
# Out:
# 15

# %% [markdown]
# 11. How many different models are there?

# %%
mpg['model'].nunique()
# Out:
# 38

# %% [markdown]
# 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg['highway'] - mpg['city']
mpg.head()
mpg['mileage_difference'].max()
mpg.sort_values('mileage_difference').tail()
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  city  highway  \
# 106        honda       civic    1.8  2008    4    auto(l5)   f    25       36
# 213   volkswagen       jetta    1.9  1999    4  manual(m5)   f    33       44
# 1           audi          a4    1.8  1999    4    auto(l5)   f    18       29
# 223   volkswagen  new beetle    1.9  1999    4    auto(l4)   f    29       41
# 107        honda       civic    1.8  2008    4    auto(l5)   f    24       36
#
#     fl       class  mileage_difference
# 106  r  subcompact                  11
# 213  d     compact                  11
# 1    p     compact                  11
# 223  d  subcompact                  12
# 107  c  subcompact                  12

# %% [markdown]
# 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg['highway'] + mpg['city']) / 2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg['is_automatic'] = (mpg.trans.str.startswith('a'))
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg.groupby('manufacturer')['average_mileage'].agg('mean').nlargest(1)
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %% [markdown]
# 16. Do automatic or manual cars have better miles per gallon?

# %%
mpg.groupby('is_automatic')['average_mileage'].agg('mean')
# Out:
# is_automatic
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64

# %% [markdown]
# # Exercises I

# %% [markdown]
# Create a notebook or python script named advanced_dataframes to do your work in for these exercises.
#
# 1. Run python -m pip install pymysql from your terminal to install the mysql client (any folder is fine)

# %%
import pandas as pd
import numpy as np
from pydataset import data
from env import host, username, password

# %% [markdown]
# 2. cd into your exercises folder for this module and run echo env.py >> .gitignore

# %%
# *.csv
# env.py
# *.ipynb_checkpoints*

# %% [markdown]
# 3. Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
import os

import env
env.username

def get_db_url(db, env_file=os.path.exists('env.py')):
    '''
    
    return a formatted string containing username, password, host and databse for connecting to the mySQL server and the database indicated.
    env_file checks to see if the env.py exists in the cwd(current working directory)
    
    '''
    
    if env_file:
        username, password, host = (env.username, env.password, env.host)
        return f'mysql+pymysql://{username}:{password}@{host}/{db}'
    else:
        return 'hello, you need a username and password to get in!'

# %% [markdown]
# 4. Use your function to obtain a connection to the employees database.

# %%
url = get_db_url('employees')
query = 'SELECT * FROM employees LIMIT 10'

# %% [markdown]
# 5. Once you have successfully run a query:
#
# a. Intentionally make a typo in the database url. What kind of error message do you see?

# %%
url = get_db_url('employeees')

# you don't get an error message

# %% [markdown]
# b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
query = 'SELt * FROM employees LIMIT 10'

# no error once again, until running the below code, then you get access denied to the mispelled database 'employees'

# %% [markdown]
# 6. Read the employees and titles tables into two separate DataFrames.

# %%
url = get_db_url('employees')

query = 'SELECT * FROM employees LIMIT 10'

df = pd.read_sql('SELECT * FROM employees LIMIT 10', url)


employees_df = pd.read_sql(query, url)
employees_df.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
query = 'SELECT * FROM titles'

titles_df = pd.read_sql('SELECT * FROM titles', url)

titles_df = pd.read_sql(query, url)
titles_df.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %% [markdown]
# 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
df.shape
# Out:
# (10, 6)

# %%
titles_df.shape
# Out:
# (443308, 4)

# %%
# yes, that is what i expected from columns and in rows.

# %% [markdown]
# 8. Display the summary statistics for each DataFrame.

# %%
df.describe()
# Out:
#             emp_no
# count     10.00000
# mean   10005.50000
# std        3.02765
# min    10001.00000
# 25%    10003.25000
# 50%    10005.50000
# 75%    10007.75000
# max    10010.00000

# %%
titles_df.describe()
# Out:
#             emp_no
# count     10.00000
# mean   10004.40000
# std        2.01108
# min    10001.00000
# 25%    10003.25000
# 50%    10004.50000
# 75%    10005.75000
# max    10007.00000

# %% [markdown]
# 9. How many unique titles are in the titles DataFrame?

# %%
titles_df['title'].nunique()
# Out:
# 7

# %% [markdown]
# 10. What is the oldest date in the to_date column?

# %%
titles_df['to_date'].min()
# Out:
# datetime.date(1985, 3, 1)

# %% [markdown]
# 10. What is the most recent date in the to_date column?

# %%
titles_df['to_date'].max()
# Out:
# datetime.date(9999, 1, 1)

# %% [markdown]
# # Exercises III

# %% [markdown]
# 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
url = get_db_url('chipotle')
query = 'SELECT * FROM orders LIMIT 100'

chipotle_df = pd.read_sql(query, url)



chipotle_df
# Out:
#      id  order_id  quantity                              item_name  \
# 0     1         1         1           Chips and Fresh Tomato Salsa
# 1     2         1         1                                   Izze
# 2     3         1         1                       Nantucket Nectar
# 3     4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4     5         2         2                           Chicken Bowl
# 5     6         3         1                           Chicken Bowl
# 6     7         3         1                          Side of Chips
# 7     8         4         1                          Steak Burrito
# 8     9         4         1                       Steak Soft Tacos
# 9    10         5         1                          Steak Burrito
# 10   11         5         1                    Chips and Guacamole
# 11   12         6         1                   Chicken Crispy Tacos
# 12   13         6         1                     Chicken Soft Tacos
# ...

# %%
chipotle_df
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %% [markdown]
# 2. What is the total price for each order?

# %%
chipotle_df['item_price_float'] = chipotle_df.item_price.str.replace('$', '').astype('float')
chipotle_df.head()

chipotle_df.groupby('order_id')['item_price_float'].agg('sum')
# Out:
# /var/folders/2g/_40bymd11_x47n42bls8ypmr0000gn/T/ipykernel_73482/313755421.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chipotle_df['item_price_float'] = chipotle_df.item_price.str.replace('$', '').astype('float')
# order_id
# 1     11.56
# 2     16.98
# 3     12.67
# 4     21.00
# 5     13.70
# 6     17.50
# 7     15.70
# 8     10.88
# 9     10.67
# 10    13.20
# 11    12.38
# 12    14.37
# 13    10.88
# 14    10.08
# 15    10.88
# 16    10.68
# 17    10.08
# 18    24.90
# 19    13.90
# 20    36.20
# 21    23.36
# 22    12.98
# 23    11.17
# 24    12.07
# 25    11.38
# 26    20.50
# 27    13.90
# 28    33.70
# 29    17.98
# 30    23.36
# 31    10.68
# 32    12.98
# 33    13.20
# 34    28.40
# 35    13.40
# 36    18.00
# 37    18.00
# 38    18.57
# 39    12.20
# 40    32.75
# 41    16.20
# 42    13.70
# 43    20.50
# ...

# %% [markdown]
# 3. What are the most popular 3 items?

# %%
most_pop = chipotle_df.groupby(['item_name']).quantity.sum()
most_pop
most_pop.sort_values(ascending = False).head(3)
# Out:
# item_name
# Chicken Burrito        12
# Chips and Guacamole    11
# Steak Burrito          11
# Name: quantity, dtype: int64

# %% [markdown]
# 4. Which item has produced the most revenue?

# %%
most_revunue = most_pop *

# %% [markdown]
# 5. Join the employees and titles DataFrames together.

# %%
df.head()
emp_title = df.merge(titles_df, on='emp_no')

# %% [markdown]
# 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %%
emp_title.groupby('title')['from_date'].agg('max')
# Out:
# title
# Assistant Engineer    1998-03-11
# Engineer              1996-11-24
# Senior Engineer       1995-12-03
# Senior Staff          1996-09-12
# Staff                 1996-08-03
# Name: from_date, dtype: object

# %% [markdown]
# 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
cross_query = '''
            SELECT t.title, d.dept_name
            FROM dept_emp
            JOIN titles t USING(emp_no)
            JOIN departments d USING(dept_no)
            WHERE t.to_date > NOW();
            '''

# %%
cross_url = get_db_url('employees')

# %%
df_cross = pd.read_sql(cross_query, cross_url)
df_cross.head()
# Out:
#              title        dept_name
# 0  Senior Engineer      Development
# 1            Staff            Sales
# 2  Senior Engineer       Production
# 3  Senior Engineer       Production
# 4     Senior Staff  Human Resources

# %%
pd.crosstab(df_cross['title'], df_cross['dept_name']).T
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                    68       627        1             1790
# Development                       1833     15677        1            43364
# Finance                              0         0        1                0
# Human Resources                      0         0        1                0
# Marketing                            0         0        1                0
# Production                        1542     13325        1            37156
# Quality Management                 433      3744        1            10390
# Research                            77       830        1             2250
# Sales                                0         0        1                0
#
# title               Senior Staff  Staff  Technique Leader
# dept_name
# Customer Service           12349   3902               241
# Development                 1085    315              6117
# ...
